# %%
import pandas as pd
df = pd.read_csv('raw_data/policy.csv')
df
# Out:
#           Date                                        Description  \
# 0    9/01/2020  World Health Organization (WHO) reports that C...
# 1   21/01/2020  COVID-19 is listed as a disease of pandemic po...
# 2   25/01/2020  First case of COVID-19 in Australia is confirmed.
# 3    1/02/2020  International travel restrictions are implemen...
# 4    1/02/2020  Travel advice for mainland China is raised to ...
# 5    3/02/2020  DFAT organises assisted departure flights from...
# 6   19/02/2020  DFAT evacuates 164 passengers from the Diamond...
# 7    1/03/2020  Inward travel restrictions on foreign national...
# 8    5/03/2020  Inward travel restrictions on foreign national...
# 9   11/03/2020  Inward travel restrictions on foreign national...
# 10  13/03/2020  Travel advice for all countries raised to ‘Lev...
# 11  15/03/2020  Compulsory 14-day self-isolation implemented f...
# 12  18/03/2020  Travel advice for all overseas countries raise...
# 13  18/03/2020  Governor-General declares a human biosecurity ...
# 14  20/03/2020  Inward travel restrictions on foreign national...
# 15  25/03/2020  Outward travel restrictions on Australians tra...
# 16  26/03/2020  DFAT arranges facilitated flights from Peru, A...
# 17  28/03/2020  Mandatory 14-day quarantine at designated hote...
# 18  10/07/2020  National Cabinet agrees on incoming passenger ...
# 19   2/09/2020  The Overseas Financial Assistance (Hardship) P...
# 20  18/09/2020  National Cabinet agrees to increase the availa...
# 21  21/09/2020  Taskforce established to bring back Australian...
# 22  13/10/2020  DFAT and Qantas enter into an agreement for fl...
# 23  20/10/2020  The Australian Government enters into an agree...
# 24  22/02/2021  The agreement for Howard Springs is varied to ...
# 25  27/04/2021     Flights from India to Australia are suspended.
# 26  14/05/2021  Flights from India for returning Australians r...
# 27  28/10/2021  The Australian Government removes the global ‘...
# 28   1/11/2021  Fully vaccinated Australians permitted to trav...
# 29  21/11/2021      DFAT closes its COVID-19 registration portal.
# 30   1/12/2021  Australian international borders reopened to f...
# 31  21/02/2022  Australian international borders reopened to i...
# 32   6/07/2022  Australian international borders reopened to i...
#
#                       Entities
# 0                          WHO
# 1                       Health
# 2                       Health
# 3         Home Affairs; Health
# 4                         DFAT
# 5                         DFAT
# 6                         DFAT
# 7                 Home Affairs
# 8                 Home Affairs
# 9                 Home Affairs
# 10                        DFAT
# 11        Home Affairs; Health
# 12                        DFAT
# 13                      Health
# 14                Home Affairs
# 15        Health; Home Affairs
# 16                        DFAT
# 17  Health; Home Affairs; PM&C
# 18                      DITRDC
# 19                        DFAT
# 20                Federal Gov.
# 21                        DFAT
# 22                        DFAT
# 23                      Health
# 24                      Health
# 25                      DITRDC
# 26                      DITRDC
# 27                        DFAT
# 28        Health; Home Affairs
# 29                        DFAT
# 30        Health; Home Affairs
# 31        Health; Home Affairs
# 32                Home Affairs

# %%
# Group by 'date' and convert each group to a list of dictionaries
dict_result = df.groupby('Date').apply(lambda x: x.to_dict(orient='records')).to_dict()
# Out:
# /tmp/ipykernel_76284/1469788069.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   dict_result = df.groupby('Date').apply(lambda x: x.to_dict(orient='records')).to_dict()

# %%
dict_result
# Out:
# {'1/02/2020': [{'Date': '1/02/2020',
#    'Description': 'International travel restrictions are implemented for foreign nationals entering Australia from China.',
#    'Entities': 'Home Affairs; Health'},
#   {'Date': '1/02/2020',
#    'Description': 'Travel advice for mainland China is raised to ‘Level 4 – Do not travel’.',
#    'Entities': 'DFAT'}],
#  '1/03/2020': [{'Date': '1/03/2020',
#    'Description': 'Inward travel restrictions on foreign nationals entering Australia from Iran implemented.',
#    'Entities': 'Home Affairs'}],
#  '1/11/2021': [{'Date': '1/11/2021',
#    'Description': 'Fully vaccinated Australians permitted to travel overseas.',
#    'Entities': 'Health; Home Affairs'}],
#  '1/12/2021': [{'Date': '1/12/2021',
#    'Description': 'Australian international borders reopened to fully vaccinated eligible visa holders.',
#    'Entities': 'Health; Home Affairs'}],
#  '10/07/2020': [{'Date': '10/07/2020',
#    'Description': 'National Cabinet agrees on incoming passenger caps at major international airports.',
#    'Entities': 'DITRDC'}],
#  '11/03/2020': [{'Date': '11/03/2020',
#    'Description': 'Inward travel restrictions on foreign nationals entering Australia from Italy implemented.',
#    'Entities': 'Home Affairs'}],
#  '13/03/2020': [{'Date': '13/03/2020',
#    'Description': 'Travel advice for all countries raised to ‘Level 3 — Reconsider your need to travel’.',
#    'Entities': 'DFAT'}],
#  '13/10/2020': [{'Date': '13/10/2020',
#    'Description': 'DFAT and Qantas enter into an agreement for flight services for 12 months.',
#    'Entities': 'DFAT'}],
#  '14/05/2021': [{'Date': '14/05/2021',
#    'Description': 'Flights from India for returning Australians resume.',
#    'Entities': 'DITRDC'}],
#  '15/03/2020': [{'Date': '15/03/2020',
#    'Description': 'Compulsory 14-day self-isolation implemented for all international arrivals.',
#    'Entities': 'Home Affairs; Health'}],
#  '18/03/2020': [{'Date': '18/03/2020',
#    'Description': 'Travel advice for all overseas countries raised to ‘Level 4 – Do not travel’.',
#    'Entities': 'DFAT'},
#   {'Date': '18/03/2020',
#    'Description': 'Governor-General declares a human biosecurity emergency period until 17 June 2020 (this was extended throughout the pandemic to until it expired in April 2022).',
#    'Entities': 'Health'}],
#  '18/09/2020': [{'Date': '18/09/2020',
#    'Description': 'National Cabinet agrees to increase the availability of quarantine places. Prime Minister states that government would seek to return overseas Australians by Christmas.',
#    'Entities': 'Federal Gov.'}],
#  '19/02/2020': [{'Date': '19/02/2020',
#    'Description': 'DFAT evacuates 164 passengers from the Diamond Princess cruise ship anchored in Tokyo.',
#    'Entities': 'DFAT'}],
#  '2/09/2020': [{'Date': '2/09/2020',
#    'Description': 'The Overseas Financial Assistance (Hardship) Program is announced.',
#    'Entities': 'DFAT'}],
#  '20/03/2020': [{'Date': '20/03/2020',
#    'Description': 'Inward travel restrictions on foreign nationals entering Australia from any country implemented.',
#    'Entities': 'Home Affairs'}],
#  '20/10/2020': [{'Date': '20/10/2020',
#    'Description': 'The Australian Government enters into an agreement with the Northern Territory Government to establish the Centre for National Resilience at Howard Springs, with quarantine capacity for 500 individuals a fortnight.',
#    'Entities': 'Health'}],
#  '21/01/2020': [{'Date': '21/01/2020',
#    'Description': 'COVID-19 is listed as a disease of pandemic potential under the Biosecurity Act 2015.',
#    'Entities': 'Health'}],
#  '21/02/2022': [{'Date': '21/02/2022',
#    'Description': 'Australian international borders reopened to include all fully vaccinated visa holders.',
#    'Entities': 'Health; Home Affairs'}],
#  '21/09/2020': [{'Date': '21/09/2020',
#    'Description': 'Taskforce established to bring back Australians registered with DFAT (as at 18 September) by Christmas 2020.',
#    'Entities': 'DFAT'}],
#  '21/11/2021': [{'Date': '21/11/2021',
#    'Description': 'DFAT closes its COVID-19 registration portal.',
#    'Entities': 'DFAT'}],
#  '22/02/2021': [{'Date': '22/02/2021',
#    'Description': 'The agreement for Howard Springs is varied to increase capacity to 2,000 individuals a fortnight from May 2021.',
#    'Entities': 'Health'}],
#  '25/01/2020': [{'Date': '25/01/2020',
#    'Description': 'First case of COVID-19 in Australia is confirmed.',
#    'Entities': 'Health'}],
#  '25/03/2020': [{'Date': '25/03/2020',
#    'Description': 'Outward travel restrictions on Australians travelling overseas implemented.',
#    'Entities': 'Health; Home Affairs'}],
#  '26/03/2020': [{'Date': '26/03/2020',
#    'Description': 'DFAT arranges facilitated flights from Peru, Argentina, South Africa, Nepal, and Uruguay, including passengers from the Ocean Atlantic cruise ship.',
#    'Entities': 'DFAT'}],
#  '27/04/2021': [{'Date': '27/04/2021',
#    'Description': 'Flights from India to Australia are suspended.',
#    'Entities': 'DITRDC'}],
#  '28/03/2020': [{'Date': '28/03/2020',
#    'Description': 'Mandatory 14-day quarantine at designated hotels and other facilities implemented by states and territories.',
#    'Entities': 'Health; Home Affairs; PM&C'}],
#  '28/10/2021': [{'Date': '28/10/2021',
#    'Description': 'The Australian Government removes the global ‘Do not travel’ advice for all destinations.',
#    'Entities': 'DFAT'}],
#  '3/02/2020': [{'Date': '3/02/2020',
#    'Description': 'DFAT organises assisted departure flights from Wuhan.',
#    'Entities': 'DFAT'}],
#  '5/03/2020': [{'Date': '5/03/2020',
#    'Description': 'Inward travel restrictions on foreign nationals entering Australia from South Korea implemented.',
#    'Entities': 'Home Affairs'}],
#  '6/07/2022': [{'Date': '6/07/2022',
#    'Description': 'Australian international borders reopened to include unvaccinated visa holders.',
#    'Entities': 'Home Affairs'}],
#  '9/01/2020': [{'Date': '9/01/2020',
#    'Description': 'World Health Organization (WHO) reports that Chinese authorities made a preliminary determination of a novel coronavirus in Wuhan.',
#    'Entities': 'WHO'}]}
